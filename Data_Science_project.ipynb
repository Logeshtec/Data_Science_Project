# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('Crimes_in_india_2001-2013.csv')
data.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
data.describe()
# Out:
#               YEAR       MURDER  ATTEMPT TO MURDER  \
# count  9840.000000  9840.000000        9840.000000
# mean   2007.161890    88.565854          78.738618
# std       3.755581   325.417692         306.650391
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          28.000000
# 75%    2010.000000    66.000000          57.000000
# max    2013.000000  7601.000000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9840.000000  9840.000000     9840.000000
# mean                                    9.754878    55.456098        0.005488
# std                                    58.733349   201.690457        0.111218
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
data.isnull().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT TO MURDER                                      0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# RAPE                                                   0
# CUSTODIAL RAPE                                         0
# OTHER RAPE                                             0
# KIDNAPPING & ABDUCTION                                 0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0
# DACOITY                                                0
# PREPARATION AND ASSEMBLY FOR DACOITY                   0
# ROBBERY                                                0
# BURGLARY                                               0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9840 non-null   object
#  1   DISTRICT                                             9840 non-null   object
#  2   YEAR                                                 9840 non-null   int64
#  3   MURDER                                               9840 non-null   int64
#  4   ATTEMPT TO MURDER                                    9840 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9840 non-null   int64
#  6   RAPE                                                 9840 non-null   int64
#  7   CUSTODIAL RAPE                                       9840 non-null   int64
# ...

# %%
data.hist(figsize=(25,15),color='gold')
# Out:
# array([[<Axes: title={'center': 'YEAR'}>,
#         <Axes: title={'center': 'MURDER'}>,
#         <Axes: title={'center': 'ATTEMPT TO MURDER'}>,
#         <Axes: title={'center': 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER'}>,
#         <Axes: title={'center': 'RAPE'}>,
#         <Axes: title={'center': 'CUSTODIAL RAPE'}>],
#        [<Axes: title={'center': 'OTHER RAPE'}>,
#         <Axes: title={'center': 'KIDNAPPING & ABDUCTION'}>,
#         <Axes: title={'center': 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS'}>,
#         <Axes: title={'center': 'KIDNAPPING AND ABDUCTION OF OTHERS'}>,
#         <Axes: title={'center': 'DACOITY'}>,
#         <Axes: title={'center': 'PREPARATION AND ASSEMBLY FOR DACOITY'}>],
#        [<Axes: title={'center': 'ROBBERY'}>,
#         <Axes: title={'center': 'BURGLARY'}>,
#         <Axes: title={'center': 'THEFT'}>,
#         <Axes: title={'center': 'AUTO THEFT'}>,
#         <Axes: title={'center': 'OTHER THEFT'}>,
# ...

# %%
data.shape
# Out:
# (9840, 33)

# %%
data.nunique()
# Out:
# STATE/UT                                                 70
# DISTRICT                                                828
# YEAR                                                     13
# MURDER                                                  498
# ATTEMPT TO MURDER                                       539
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               174
# RAPE                                                    449
# CUSTODIAL RAPE                                            5
# OTHER RAPE                                              448
# KIDNAPPING & ABDUCTION                                  591
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             507
# KIDNAPPING AND ABDUCTION OF OTHERS                      327
# DACOITY                                                 237
# PREPARATION AND ASSEMBLY FOR DACOITY                    200
# ROBBERY                                                 486
# BURGLARY                                                962
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('Crimes_in_india_2001-2013.csv')
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9835    False
# 9836    False
# 9837    False
# 9838    False
# 9839    False
# Length: 9840, dtype: bool

# %%
#mean
num=df['ATTEMPT TO MURDER']
def find_mean(list_of_num):
    sum_n=sum(list_of_num)
    len_n=len(list_of_num)
    mean=sum_n/len_n
    return mean
result=find_mean(num)
print(result)
# Out:
# 78.73861788617886

# %%
df1=df.drop_duplicates()
df1
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9835     Lakshadweep    LAKSHADWEEP  2013       0                  0
# 9836     Lakshadweep       ZZ TOTAL  2013       0                  0
# 9837      Puducherry       KARAIKAL  2013       6                  3
# 9838      Puducherry     PUDUCHERRY  2013      25                  8
# 9839      Puducherry       ZZ TOTAL  2013      31                 11
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv('Crimes_in_india_2001-2013.csv').head(150)
data={
    'DISTRICT':dataset['CHEATING'],
    'STATE/UT':dataset['HURT/GREVIOUS HURT']
     }
df=pd.DataFrame(data)
z_score=np.abs((df-df.mean())/df.std())
thershold=2
outliers=z_score>thershold
df_no_outliers=df[(z_score<thershold).all(axis=1)]
print("original dataframe")
print(df)
print("\nz_score:")
print(z_score)
print("\nOutliers detected:")
print(outliers)
print("\nDataframe after removing:")
print(df_no_outliers)
# Out:
# original dataframe
#      DISTRICT  STATE/UT
# 0         104      1131
# 1          65      1543
# 2         209      2088
# 3          37       795
# 4         220      1244
# ..        ...       ...
# 145       103       100
# 146         0       394
# 147        38       430
# 148        52       357
# 149        25       418
#
# [150 rows x 2 columns]
#
# z_score:
#      DISTRICT  STATE/UT
# 0    0.017447  0.124995
# 1    0.099622  0.263045
# 2    0.203796  0.445659
# 3    0.158620  0.012411
# 4    0.226973  0.162858
# ..        ...       ...
# 145  0.019554  0.220464
# 146  0.236582  0.121953
# 147  0.156513  0.109890
# 148  0.127014  0.134350
# 149  0.183905  0.113911
#
# [150 rows x 2 columns]
#
# Outliers detected:
#      DISTRICT  STATE/UT
# 0       False     False
# 1       False     False
# 2       False     False
# 3       False     False
# 4       False     False
# ..        ...       ...
# 145     False     False
# 146     False     False
# 147     False     False
# ...

# %%
data1=df_no_outliers
data1
data1.plot(kind='bar',color='green')
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv('Crimes_in_india_2001-2013.csv').tail(60)
data={
    'DISTRICT':dataset['CHEATING'],
    'STATE/UT':dataset['ROBBERY']
     }
df=pd.DataFrame(data)
df_unique=df.drop_duplicates()
plt.figure(figsize=(12,6))

#plot original data
plt.subplot(1,2,1)
plt.plot(df.index,df['STATE/UT'],marker='o',linestyle='-',alpha=0.8,color='orange')
plt.title('Original value')
plt.xlabel('Index')
plt.ylabel('Age')
plt.grid(True)

#plot duplicate data
plt.subplot(1,2,2)
plt.plot(df_unique.index,df_unique['STATE/UT'],marker='o',alpha=0.8,linestyle='-',color='purple')
plt.title('data after removing duplicates')
plt.xlabel('Index')
plt.ylabel('Age')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import statistics
dataset=pd.read_csv('Crimes_in_india_2001-2013.csv').head(1000)
sample=dataset['TOTAL IPC CRIMES']
print("standard deviation is %s",statistics.stdev(sample))
# Out:
# standard deviation is %s 15931.428681396701

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('Crimes_in_india_2001-2013.csv').head(4500)
data['YEAR'].value_counts().plot.pie(autopct='%1.1f%%',startangle=0,wedgeprops={'edgecolor':'white','antialiased':True,'linewidth': 2})
plt.legend()

# %%
# Example: Extract year from a date column
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv('Crimes_in_india_2001-2013.csv').tail(25)
data={
    'TOTAL IPC CRIMES':dataset['TOTAL IPC CRIMES']
     }
df=pd.DataFrame(data)
df['Year'] = pd.to_datetime(df['TOTAL IPC CRIMES']).dt.year
df
# Out:
#       TOTAL IPC CRIMES  Year
# 9815               246  1970
# 9816               203  1970
# 9817              4562  1970
# 9818                80  1970
# 9819             10388  1970
# 9820               163  1970
# 9821               760  1970
# 9822               351  1970
# 9823               962  1970
# 9824              1458  1970
# 9825              4081  1970
# 9826              9041  1970
# 9827              6564  1970
# 9828              9579  1970
# 9829              8593  1970
# 9830              8608  1970
# 9831              5963  1970
# 9832                15  1970
# 9833              8813  1970
# 9834             80184  1970
# 9835                40  1970
# 9836                40  1970
# 9837               643  1970
# 9838              3113  1970
# 9839              3756  1970

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
dataset=pd.read_csv('Crimes_in_india_2001-2013.csv').tail(20)
data={
    'YEAR':dataset['OTHER IPC CRIMES'],
    'TOTAL IPC CRIMES':dataset['TOTAL IPC CRIMES']
     }
df=pd.DataFrame(data)
scaler = StandardScaler()
ds= scaler.fit_transform(df)
print("\nCrimerate:",ds)
# Out:
# Crimerate: [[-0.44428234 -0.43939632]
#  [-0.43744459 -0.40429565]
#  [-0.4135125  -0.42834284]
#  [-0.45774414 -0.39241904]
#  [-0.35282753 -0.36325667]
#  [-0.21970522 -0.20903714]
#  [ 0.02068417  0.08258653]
#  [-0.15709714 -0.06304892]
#  [ 0.06427478  0.11421829]
#  [ 0.04461627  0.05624633]
#  [ 0.07004413  0.05712825]
#  [-0.03401777 -0.09838477]
#  [-0.46137669 -0.448098  ]
#  [ 0.04910354  0.06918125]
#  [ 4.26649508  4.26544596]
#  [-0.45838518 -0.44662812]
#  [-0.45838518 -0.44662812]
#  [-0.39193087 -0.41117468]
#  [-0.14940468 -0.26595079]
#  [-0.07910414 -0.22814555]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('Crimes_in_india_2001-2013.csv')
data.groupby('YEAR')['TOTAL IPC CRIMES'].mean().plot(kind='line',color='blue')
plt.title('Average Crime Rate Over Time')
plt.xlabel('Year')
plt.ylabel('Average Crime Rate')
plt.grid()
plt.legend()
plt.show()

# %%
import seaborn as sns
data=pd.read_csv('Crimes_in_india_2001-2013.csv').tail(500)
plt.figure(figsize=(7, 6))
sns.barplot(x='STATE/UT', y='TOTAL IPC CRIMES',color='orange', data=data)
plt.title('Crime Rate by State')
plt.xticks(rotation=90)
plt.show()

# %%
import numpy as np
dataset=pd.read_csv('Crimes_in_india_2001-2013.csv').head(5000)
data={
    'other crimes':dataset['OTHER IPC CRIMES'],
    'state':dataset['YEAR'],
    'total crime':dataset['TOTAL IPC CRIMES'],
    'murder':dataset['MURDER']   
}
df = pd.DataFrame(data)
correlation_matrix = df.corr()
print(correlation_matrix)
import seaborn as sns
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='inferno', vmin=-1, vmax=1, fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
#               other crimes     state  total crime    murder
# other crimes      1.000000  0.011699     0.959052  0.720719
# state             0.011699  1.000000     0.007388 -0.016531
# total crime       0.959052  0.007388     1.000000  0.818311
# murder            0.720719 -0.016531     0.818311  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv('Crimes_in_india_2001-2013.csv').head(15)
x=dataset['DISTRICT']
y=dataset['MURDER']
plt.bar(x,y,color='r',alpha=0.8)
plt.title("Bar")
plt.xlabel('total')
plt.ylabel('tip')
plt.show()
